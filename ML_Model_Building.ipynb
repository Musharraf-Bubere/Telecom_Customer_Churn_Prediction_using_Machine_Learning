# %%
# Importing Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
# Read the file

df = pd.read_csv('Customer-Churn.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 0  7590-VHVEG  Female              0  ...          29.85        29.85     No
# 1  5575-GNVDE    Male              0  ...          56.95       1889.5     No
# 2  3668-QPYBK    Male              0  ...          53.85       108.15    Yes
# 3  7795-CFOCW    Male              0  ...          42.30      1840.75     No
# 4  9237-HQITU  Female              0  ...          70.70       151.65    Yes
#
# [5 rows x 21 columns]

# %%
df.Churn.value_counts()/len(df)*100
# Out:
# Churn
# No     73.463013
# Yes    26.536987
# Name: count, dtype: float64

# %% [markdown]
# ### **Churn Rate: 26.53%
#
# - Which means, 26.53% of the customers churn out of this telecom company

# %%
# Divide data into X and y - X (Independent feature), y (Dependent variable)

# Define y (target variable)
y = df['Churn']

# Define X (features) by dropping 'customerID' and 'Churn'
X = df.drop(columns=['customerID', 'Churn'])

# Optional: Verify the shapes
print("Shape of X:", X.shape)
print("Shape of y:", y.shape)
# Out:
# Shape of X: (7043, 19)
# Shape of y: (7043,)

# %% [markdown]
# # Train Test Split

# %%
X = pd.get_dummies(X, drop_first=True)
y = df['Churn'].map({'No':0, 'Yes':1})

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# # Model Building

# %%
model_dt = DecisionTreeClassifier()
model_dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_dt = model_dt.predict(X_test)

# %%
print(classification_report(y_test, y_pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.87      0.85      1044
#            1       0.56      0.46      0.51       365
#
#     accuracy                           0.77      1409
#    macro avg       0.69      0.67      0.68      1409
# weighted avg       0.75      0.77      0.76      1409

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %% [markdown]
# # **Initial Insights**
#
# - Base model has a accuracy of 76% which is not reliable because of the imbalance dataset
# - TotalCharges needs to be a float/int type (Data Cleaning)
# - Need to perform Feature Scaling

# %% [markdown]
# # Data Cleaning

# %%
telco_data = df.copy()

# %%
telco_data.TotalCharges = pd.to_numeric(telco_data.TotalCharges, errors='coerce')

# %%
telco_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7032 non-null   float64
#  20  Churn             7043 non-null   object
# dtypes: float64(2), int64(2), object(17)
# memory usage: 1.1+ MB

# %%
telco_data.loc[telco_data['TotalCharges'].isnull() == True]
# Out:
#       customerID  gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 488   4472-LVYGI  Female              0  ...          52.55          NaN     No
# 753   3115-CZMZD    Male              0  ...          20.25          NaN     No
# 936   5709-LVOEQ  Female              0  ...          80.85          NaN     No
# 1082  4367-NUYAO    Male              0  ...          25.75          NaN     No
# 1340  1371-DWPAZ  Female              0  ...          56.05          NaN     No
# 3331  7644-OMVMY    Male              0  ...          19.85          NaN     No
# 3826  3213-VVOLG    Male              0  ...          25.35          NaN     No
# 4380  2520-SGTTA  Female              0  ...          20.00          NaN     No
# 5218  2923-ARZLG    Male              0  ...          19.70          NaN     No
# 6670  4075-WKNIU  Female              0  ...          73.35          NaN     No
# 6754  2775-SEFEE    Male              0  ...          61.90          NaN     No
#
# [11 rows x 21 columns]

# %%
telco_data.dropna(how='any', inplace=True)

# %%
telco_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7032 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   object
#  1   gender            7032 non-null   object
#  2   SeniorCitizen     7032 non-null   int64
#  3   Partner           7032 non-null   object
#  4   Dependents        7032 non-null   object
#  5   tenure            7032 non-null   int64
#  6   PhoneService      7032 non-null   object
#  7   MultipleLines     7032 non-null   object
#  8   InternetService   7032 non-null   object
#  9   OnlineSecurity    7032 non-null   object
#  10  OnlineBackup      7032 non-null   object
#  11  DeviceProtection  7032 non-null   object
#  12  TechSupport       7032 non-null   object
#  13  StreamingTV       7032 non-null   object
#  14  StreamingMovies   7032 non-null   object
#  15  Contract          7032 non-null   object
#  16  PaperlessBilling  7032 non-null   object
#  17  PaymentMethod     7032 non-null   object
#  18  MonthlyCharges    7032 non-null   float64
#  19  TotalCharges      7032 non-null   float64
#  20  Churn             7032 non-null   object
# dtypes: float64(2), int64(2), object(17)
# memory usage: 1.2+ MB

# %%
# Define the bin edges (0 to 72, stepping by 12 months)
bins = [0, 12, 24, 36, 48, 60, 72]

# Define the labels for each bin
labels = ['1-12', '13-24', '15-36', '36-48', '49-60', '61-72']

# Create the new binned column
telco_data['tenure_bin'] = pd.cut(telco_data['tenure'], bins=bins, labels=labels, include_lowest=True)

# Optional: Check the result
print(telco_data[['tenure', 'tenure_bin']].head(10))
print(telco_data['tenure_bin'].value_counts().sort_index())
# Out:
#    tenure tenure_bin
# 0       1       1-12
# 1      34      15-36
# 2       2       1-12
# 3      45      36-48
# 4       2       1-12
# 5       8       1-12
# 6      22      13-24
# 7      10       1-12
# 8      28      15-36
# 9      62      61-72
# tenure_bin
# 1-12     2175
# 13-24    1024
# 15-36     832
# 36-48     762
# 49-60     832
# 61-72    1407
# Name: count, dtype: int64

# %%
# Divide data into X and y - X (Independent feature), y (Dependent variable)

# Define y (target variable)
y = telco_data['Churn']

# Define X (features) by dropping 'customerID' and 'Churn'
X = telco_data.drop(columns=['customerID', 'Churn', 'tenure'])

# Optional: Verify the shapes
print("Shape of X:", X.shape)
print("Shape of y:", y.shape)
# Out:
# Shape of X: (7032, 19)
# Shape of y: (7032,)

# %%
X = pd.get_dummies(X, drop_first=True)
y = telco_data['Churn'].map({'No':0, 'Yes':1})

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# # Feature Scaling

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
model_dt2 = DecisionTreeClassifier()
model_dt2.fit(X_train, y_train)

y_pred_dt2 = model_dt2.predict(X_test)

# %%
print(classification_report(y_test, y_pred_dt2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.81      0.80      1018
#            1       0.48      0.47      0.48       389
#
#     accuracy                           0.71      1407
#    macro avg       0.64      0.64      0.64      1407
# weighted avg       0.71      0.71      0.71      1407

# %% [markdown]
# # Feature Scaling - MinmaxScaler

# %%
mms = MinMaxScaler()
X_train_mms = mms.fit_transform(X_train)
X_test_mms = mms.transform(X_test)

# %%
model_dt3 = DecisionTreeClassifier()
model_dt3.fit(X_train_mms, y_train)

y_pred_dt3 = model_dt3.predict(X_test_mms)

# %%
print(classification_report(y_test, y_pred_dt3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80      1018
#            1       0.48      0.48      0.48       389
#
#     accuracy                           0.71      1407
#    macro avg       0.64      0.64      0.64      1407
# weighted avg       0.71      0.71      0.71      1407

# %% [markdown]
# ### SMOTEENN () [UpSampling + ENN]

# %%
from imblearn.combine import SMOTEENN

# %%
sm = SMOTEENN()
X_train_resampled, y_train_resampled = sm.fit_resample(X_train, y_train)

# %%
model_dt_smoteenn = DecisionTreeClassifier()
model_dt_smoteenn.fit(X_train_resampled, y_train_resampled)

y_pred_dt_smoteenn = model_dt_smoteenn.predict(X_test)

# %%
print(classification_report(y_test, y_pred_dt_smoteenn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.71      0.79      1018
#            1       0.51      0.78      0.61       389
#
#     accuracy                           0.73      1407
#    macro avg       0.70      0.75      0.70      1407
# weighted avg       0.79      0.73      0.74      1407

# %%
model_rf_smoteenn = RandomForestClassifier()
model_rf_smoteenn.fit(X_train_resampled, y_train_resampled)

y_pred_rf_smoteenn = model_rf_smoteenn.predict(X_test)

# %%
print(classification_report(y_test, y_pred_rf_smoteenn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.72      0.80      1018
#            1       0.52      0.81      0.64       389
#
#     accuracy                           0.74      1407
#    macro avg       0.72      0.76      0.72      1407
# weighted avg       0.80      0.74      0.76      1407

# %% [markdown]
# ### XGBoost without SMOTEENN

# %%
from xgboost import XGBClassifier

# Initialize and train the XGBoost model
model_xgb = XGBClassifier(random_state=42) # random_state for reproducibility
model_xgb.fit(X_train, y_train)

# Make predictions on the test set
y_pred_xgb = model_xgb.predict(X_test)

# %%
print(classification_report(y_test, y_pred_xgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.89      0.86      1018
#            1       0.65      0.56      0.60       389
#
#     accuracy                           0.79      1407
#    macro avg       0.74      0.72      0.73      1407
# weighted avg       0.79      0.79      0.79      1407

# %% [markdown]
# ### XGBoost with SMOTEENN

# %%
from xgboost import XGBClassifier

# Initialize and train the XGBoost model
model_xgb_smoteenn = XGBClassifier(random_state=42) # random_state for reproducibility
model_xgb_smoteenn.fit(X_train_resampled, y_train_resampled)

# Make predictions on the test set
y_pred_xgb_smoteenn = model_xgb_smoteenn.predict(X_test)

# %%
print(classification_report(y_test, y_pred_xgb_smoteenn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.73      0.81      1018
#            1       0.53      0.80      0.64       389
#
#     accuracy                           0.75      1407
#    macro avg       0.72      0.76      0.72      1407
# weighted avg       0.80      0.75      0.76      1407

# %% [markdown]
# ### XGBoost with SMOTE

# %%
from imblearn.over_sampling import SMOTE
from xgboost import XGBClassifier
from collections import Counter

# Check class distribution before SMOTE
print("Before SMOTE:", Counter(y_train))

# Apply SMOTE to the training data only
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# Check class distribution after SMOTE
print("After SMOTE:", Counter(y_train_smote))

# Initialize and train the XGBoost model on resampled data
model_xgb_smote = XGBClassifier(random_state=42)
model_xgb_smote.fit(X_train_smote, y_train_smote)

# Make predictions on the original test set (unchanged)
y_pred_xgb_smote = model_xgb_smote.predict(X_test)
# Out:
# Before SMOTE: Counter({0: 4145, 1: 1480})
# After SMOTE: Counter({0: 4145, 1: 4145})

# %%
print(classification_report(y_test, y_pred_xgb_smote))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.86      0.85      1018
#            1       0.61      0.58      0.59       389
#
#     accuracy                           0.78      1407
#    macro avg       0.73      0.72      0.72      1407
# weighted avg       0.78      0.78      0.78      1407

# %% [markdown]
# ### XGBoost with ADASYN

# %%
from imblearn.over_sampling import ADASYN
from xgboost import XGBClassifier
from collections import Counter

# Check original distribution
print("Before ADASYN:", Counter(y_train))

# Apply ADASYN to training data only
adasyn = ADASYN(random_state=42)
X_train_adasyn, y_train_adasyn = adasyn.fit_resample(X_train, y_train)

# Check new distribution
print("After ADASYN:", Counter(y_train_adasyn))

# Train XGBoost on ADASYN-resampled data
model_xgb_adasyn = XGBClassifier(random_state=42)
model_xgb_adasyn.fit(X_train_adasyn, y_train_adasyn)

# Predict on the original test set
y_pred_xgb_adasyn =model_xgb_adasyn.predict(X_test)

# Evaluate
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

print("Accuracy:", accuracy_score(y_test, y_pred_xgb_adasyn))
print("\nClassification Report:\n", classification_report(y_test, y_pred_xgb_adasyn))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred_xgb_adasyn))
# Out:
# Before ADASYN: Counter({0: 4145, 1: 1480})
# After ADASYN: Counter({0: 4145, 1: 4130})
# Accuracy: 0.7860696517412935
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.86      0.85      1018
#            1       0.62      0.58      0.60       389
#
#     accuracy                           0.79      1407
#    macro avg       0.73      0.72      0.73      1407
# weighted avg       0.78      0.79      0.78      1407
#
#
# Confusion Matrix:
#  [[879 139]
#  [162 227]]

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Calculate scale_weight (ratio of negative to possitive class)
scale_pos_weight = (y_train == 0).sum() / (y_train == 1).sum()
print(f"scale_pos_weight: {scale_pos_weight:.2f}")

# Train XGBoost with scale_pos_weight
model_xgb_weighted = XGBClassifier(
    scale_pos_weight=scale_pos_weight,
    random_state=42, 
    eval_metric='logloss' # avoids warnings
    )

model_xgb_weighted.fit(X_train, y_train)
y_pred_weighted = model_xgb_weighted.predict(X_test)

# Evaluate
print("Accuracy:", accuracy_score(y_test, y_pred_weighted))
print("\nclassifciation Report:\n", classification_report(y_test, y_pred_weighted))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred_weighted))
# Out:
# scale_pos_weight: 2.80
# Accuracy: 0.7633262260127932
#
# classifciation Report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.79      0.83      1018
#            1       0.56      0.68      0.62       389
#
#     accuracy                           0.76      1407
#    macro avg       0.71      0.74      0.72      1407
# weighted avg       0.78      0.76      0.77      1407
#
#
# Confusion Matrix:
#  [[808 210]
#  [123 266]]

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import numpy as np

# Calculate the weight for the positive (minority) class
# Common approach: weight_positive = negative_count / positive_count
negative_count = (y_train == 0).sum()
positive_count = (y_train == 1).sum()
weight_positive = negative_count / positive_count if positive_count > 0 else 1
print(f"Negative class count: {negative_count}")
print(f"Positive class count: {positive_count}")
print(f"Weight for positive class: {weight_positive:.2f}")

# Create sample weights: higher weight for minority class
sample_weight = np.where(y_train == 1, weight_positive, 1.0)

# Train AdaBoost with sample weights
model_ada_weighted = AdaBoostClassifier(
    n_estimators=50,  # default, you can tune
    random_state=42
)

model_ada_weighted.fit(X_train, y_train, sample_weight=sample_weight)

# Predict and evaluate
y_pred_ada_weighted = model_ada_weighted.predict(X_test)

print("AdaBoost with sample weighting - Accuracy:", accuracy_score(y_test, y_pred_ada_weighted))
print("\nClassification Report:\n", classification_report(y_test, y_pred_ada_weighted))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred_ada_weighted))
# Out:
# Negative class count: 4145
# Positive class count: 1480
# Weight for positive class: 2.80
# AdaBoost with sample weighting - Accuracy: 0.7540867093105899
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.73      0.81      1018
#            1       0.54      0.83      0.65       389
#
#     accuracy                           0.75      1407
#    macro avg       0.73      0.78      0.73      1407
# weighted avg       0.81      0.75      0.77      1407
#
#
# Confusion Matrix:
#  [[740 278]
#  [ 68 321]]

# %% [markdown]
# ### **Hyper Parameter Optimization**

# %%
from sklearn.model_selection import RandomizedSearchCV
from xgboost import XGBClassifier

param_grid = {
    'max_depth': [3, 4, 5, 6, 7],
    'learning_rate': [0.01, 0.05, 0.1, 0.2],
    'n_estimators': [100, 200, 300, 400],
    'subsample': [0.7, 0.8, 0.9, 1.0],
    'colsample_bytree': [0.7, 0.8, 0.9, 1.0],
    'min_child_weight': [1, 3, 5],
    'gamma': [0, 0.1, 0.2],
    'scale_pos_weight': [1, scale_pos_weight] # try both balanced and weighted
}

xgb = XGBClassifier(random_state=42, eval_metric='logloss')

# Use 'f1' or 'recall' scoring since churn is imbalanced
search = RandomizedSearchCV(
    xgb,
    param_grid,
    n_iter=50,
    cv=5,
    scoring='f1',  # or 'recall' if catching churn is priority
    random_state=42,
    n_jobs=-1
)

search.fit(X_train, y_train)

print("Best parameters:", search.best_params_)
print("Best CV F1 score:", search.best_score_)

# Use best model
best_model = search.best_estimator_
y_pred_best = best_model.predict(X_test)
print("\nTest Classification Report:\n", classification_report(y_test, y_pred_best))
# Out:
# Best parameters: {'subsample': 0.8, 'scale_pos_weight': np.float64(2.800675675675676), 'n_estimators': 400, 'min_child_weight': 5, 'max_depth': 4, 'learning_rate': 0.01, 'gamma': 0, 'colsample_bytree': 0.7}
# Best CV F1 score: 0.6256985293859109
#
# Test Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.74      0.82      1018
#            1       0.55      0.82      0.66       389
#
#     accuracy                           0.76      1407
#    macro avg       0.73      0.78      0.74      1407
# weighted avg       0.81      0.76      0.77      1407

# %%
# Save this model

import joblib

# Save the best model to a .pkl file
joblib.dump(best_model, 'best_xgboost_churn_model.pkl')

print("Best model successfully saved as 'best_xgboost_churn_model.pkl'")
# Out:
# Best model successfully saved as 'best_xgboost_churn_model.pkl'

# %% [markdown]
# ### Trying out few more techniques

# %%
from sklearn.ensemble import RandomForestClassifier

model_rf = RandomForestClassifier(
    class_weight='balanced',
    random_state=42,
    n_estimators=300,
    max_depth=6
)

model_rf.fit(X_train, y_train)
y_pred_rf = model_rf.predict(X_test)
print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.73      0.81      1018
#            1       0.54      0.83      0.65       389
#
#     accuracy                           0.75      1407
#    macro avg       0.73      0.78      0.73      1407
# weighted avg       0.81      0.75      0.77      1407

# %%
from catboost import CatBoostClassifier

model_cat = CatBoostClassifier(
    auto_class_weights='Balanced',  # or 'SqrtBalanced'
    verbose=0,
    random_state=42
)
model_cat.fit(X_train, y_train)
y_pred_cat = model_cat.predict(X_test)
print(classification_report(y_test, y_pred_cat))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.78      0.83      1018
#            1       0.57      0.77      0.65       389
#
#     accuracy                           0.78      1407
#    macro avg       0.73      0.77      0.74      1407
# weighted avg       0.81      0.78      0.78      1407

# %%
from lightgbm import LGBMClassifier

model_lgb = LGBMClassifier(
    scale_pos_weight=scale_pos_weight,
    random_state=42
)
model_lgb.fit(X_train, y_train)
y_pred_lgb = model_lgb.predict(X_test)
print(classification_report(y_test, y_pred_lgb))
# Out:
# [LightGBM] [Info] Number of positive: 1480, number of negative: 4145
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000880 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 606
# [LightGBM] [Info] Number of data points in the train set: 5625, number of used features: 34
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.263111 -> initscore=-1.029861
# [LightGBM] [Info] Start training from score -1.029861
#               precision    recall  f1-score   support
#
#            0       0.89      0.76      0.82      1018
#            1       0.55      0.76      0.64       389
#
#     accuracy                           0.76      1407
#    macro avg       0.72      0.76      0.73      1407
# weighted avg       0.80      0.76      0.77      1407
# d:\Telecom_Customer_Churn_Prediction_using_Machine_Learning\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ### **Optuna Fine Tuning**

# %%
import optuna
from sklearn.model_selection import cross_val_score
from xgboost import XGBClassifier
from sklearn.metrics import f1_score, make_scorer

def objective(trial):
    params = {
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'gamma': trial.suggest_float('gamma', 0, 0.5),
        'reg_alpha': trial.suggest_float('reg_alpha', 0, 1),  # L1 regularization
        'reg_lambda': trial.suggest_float('reg_lambda', 0, 2), # L2 regularization
        'scale_pos_weight': trial.suggest_categorical('scale_pos_weight', [1, scale_pos_weight]),
        'random_state': 42,
        'eval_metric': 'logloss'
    }

    model = XGBClassifier(**params)

    # Use F1 for minority class as scorer
    f1_scorer = make_scorer(f1_score, average='binary', pos_label=1)
    score = cross_val_score(model, X_train, y_train, cv=5, scoring=f1_scorer, n_jobs=-1).mean()

    return score

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)  # Increase trials for better results

print("Best parameters:", study.best_params)
print("Best CV F1 score:", study.best_value)

# Train final model with best params
best_model_optuna = XGBClassifier(**study.best_params)
best_model_optuna.fit(X_train, y_train)
y_pred_optuna = best_model_optuna.predict(X_test)
print(classification_report(y_test, y_pred_optuna))
# Out:
# [I 2026-02-07 21:13:38,233] A new study created in memory with name: no-name-cfc0d1d8-31c8-4558-9d78-3ef65daeea6a
# [I 2026-02-07 21:13:40,349] Trial 0 finished with value: 0.5631112721892338 and parameters: {'max_depth': 9, 'learning_rate': 0.10681983161989432, 'n_estimators': 840, 'subsample': 0.780614953531384, 'colsample_bytree': 0.667472038016988, 'min_child_weight': 8, 'gamma': 0.4755029158282375, 'reg_alpha': 0.3259847594949741, 'reg_lambda': 1.8738536787984807, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 0 with value: 0.5631112721892338.
# [I 2026-02-07 21:13:41,557] Trial 1 finished with value: 0.5475574899202104 and parameters: {'max_depth': 3, 'learning_rate': 0.16013107504618393, 'n_estimators': 671, 'subsample': 0.6027910032327594, 'colsample_bytree': 0.8589800915727963, 'min_child_weight': 10, 'gamma': 0.1618927058309687, 'reg_alpha': 0.6507157346751621, 'reg_lambda': 0.5579807807259112, 'scale_pos_weight': 1}. Best is trial 0 with value: 0.5631112721892338.
# [I 2026-02-07 21:13:43,443] Trial 2 finished with value: 0.5537989877741869 and parameters: {'max_depth': 6, 'learning_rate': 0.03713132577825512, 'n_estimators': 782, 'subsample': 0.7088628686527492, 'colsample_bytree': 0.6493760271291067, 'min_child_weight': 3, 'gamma': 0.3685477819987039, 'reg_alpha': 0.9187402348828505, 'reg_lambda': 1.3491081248037913, 'scale_pos_weight': 1}. Best is trial 0 with value: 0.5631112721892338.
# [I 2026-02-07 21:13:44,929] Trial 3 finished with value: 0.5309534517261838 and parameters: {'max_depth': 10, 'learning_rate': 0.1165981955274092, 'n_estimators': 386, 'subsample': 0.9341837576575899, 'colsample_bytree': 0.9301168401702931, 'min_child_weight': 4, 'gamma': 0.1383079609354939, 'reg_alpha': 0.18049319571345268, 'reg_lambda': 0.8294420494733814, 'scale_pos_weight': 1}. Best is trial 0 with value: 0.5631112721892338.
# [I 2026-02-07 21:13:46,721] Trial 4 finished with value: 0.5601348730503226 and parameters: {'max_depth': 3, 'learning_rate': 0.024669670004833194, 'n_estimators': 946, 'subsample': 0.7457056207226594, 'colsample_bytree': 0.8553330640914525, 'min_child_weight': 2, 'gamma': 0.08734622558559307, 'reg_alpha': 0.21442801686480306, 'reg_lambda': 1.5322247974623808, 'scale_pos_weight': 1}. Best is trial 0 with value: 0.5631112721892338.
# [I 2026-02-07 21:13:47,851] Trial 5 finished with value: 0.612819960697409 and parameters: {'max_depth': 4, 'learning_rate': 0.032308280010494225, 'n_estimators': 558, 'subsample': 0.8075400577275444, 'colsample_bytree': 0.6453767461684345, 'min_child_weight': 7, 'gamma': 0.01837918693549845, 'reg_alpha': 0.8482238806243743, 'reg_lambda': 0.45959798714370015, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 5 with value: 0.612819960697409.
# [I 2026-02-07 21:13:49,037] Trial 6 finished with value: 0.553865468828565 and parameters: {'max_depth': 9, 'learning_rate': 0.025698413278083525, 'n_estimators': 349, 'subsample': 0.8960891729959064, 'colsample_bytree': 0.9506777562925471, 'min_child_weight': 5, 'gamma': 0.08219522167760007, 'reg_alpha': 0.6997419219645118, 'reg_lambda': 0.0918441314542302, 'scale_pos_weight': 1}. Best is trial 5 with value: 0.612819960697409.
# [I 2026-02-07 21:13:51,408] Trial 7 finished with value: 0.574841616548556 and parameters: {'max_depth': 9, 'learning_rate': 0.06817975924969812, 'n_estimators': 762, 'subsample': 0.6126789727293754, 'colsample_bytree': 0.7152958547186952, 'min_child_weight': 7, 'gamma': 0.405312326070575, 'reg_alpha': 0.9221988848122615, 'reg_lambda': 0.6524186751599539, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 5 with value: 0.612819960697409.
# [I 2026-02-07 21:13:53,722] Trial 8 finished with value: 0.5387393424423906 and parameters: {'max_depth': 9, 'learning_rate': 0.10085940537569868, 'n_estimators': 979, 'subsample': 0.6835823164449397, 'colsample_bytree': 0.6029758378408733, 'min_child_weight': 9, 'gamma': 0.34530086402297877, 'reg_alpha': 0.08210023766228858, 'reg_lambda': 1.5245553806157552, 'scale_pos_weight': 1}. Best is trial 5 with value: 0.612819960697409.
# [I 2026-02-07 21:13:54,288] Trial 9 finished with value: 0.6205299420621986 and parameters: {'max_depth': 4, 'learning_rate': 0.011769794378491153, 'n_estimators': 194, 'subsample': 0.7436348340543983, 'colsample_bytree': 0.9632435434216347, 'min_child_weight': 7, 'gamma': 0.055219566393640174, 'reg_alpha': 0.4201949566333686, 'reg_lambda': 1.8409833450603659, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 9 with value: 0.6205299420621986.
# [I 2026-02-07 21:13:54,786] Trial 10 finished with value: 0.6169257121189288 and parameters: {'max_depth': 6, 'learning_rate': 0.010666033897777816, 'n_estimators': 101, 'subsample': 0.8560604268422226, 'colsample_bytree': 0.9830796423527555, 'min_child_weight': 1, 'gamma': 0.24664468433533532, 'reg_alpha': 0.46156450281742567, 'reg_lambda': 1.8790845075335283, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 9 with value: 0.6205299420621986.
# [I 2026-02-07 21:13:55,265] Trial 11 finished with value: 0.6164801019469783 and parameters: {'max_depth': 6, 'learning_rate': 0.010660104077664575, 'n_estimators': 100, 'subsample': 0.8454686183153876, 'colsample_bytree': 0.9896975583446997, 'min_child_weight': 1, 'gamma': 0.2544464791797273, 'reg_alpha': 0.4376965912114469, 'reg_lambda': 1.9794261489426066, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial
 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 23 with value: 0.6284977463885927.
# [I 2026-02-07 21:14:11,133] Trial 27 finished with value: 0.6188733983008794 and parameters: {'max_depth': 5, 'learning_rate': 0.03086686368876741, 'n_estimators': 367, 'subsample': 0.6486800791010229, 'colsample_bytree': 0.6813715640794538, 'min_child_weight': 4, 'gamma': 0.19713362719125732, 'reg_alpha': 0.06954318686602355, 'reg_lambda': 1.24325391725782, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 23 with value: 0.6284977463885927.
# [I 2026-02-07 21:14:11,858] Trial 28 finished with value: 0.625406256661948 and parameters: {'max_depth': 3, 'learning_rate': 0.013078679079600442, 'n_estimators': 379, 'subsample': 0.7087126075795821, 'colsample_bytree': 0.6904986214882586, 'min_child_weight': 4, 'gamma': 0.3139647423360652, 'reg_alpha': 0.5728499779750861, 'reg_lambda': 0.7894138194219935, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 23 with value: 0.6284977463885927.
# [I 2026-02-07 21:14:12,723] Trial 29 finished with value: 0.622166746777497 and parameters: {'max_depth': 4, 'learning_rate': 0.03279468275791047, 'n_estimators': 423, 'subsample': 0.77026556778586, 'colsample_bytree': 0.6109016975439215, 'min_child_weight': 1, 'gamma': 0.15950787540637223, 'reg_alpha': 0.2861947887445175, 'reg_lambda': 1.570938702048722, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 23 with value: 0.6284977463885927.
# [I 2026-02-07 21:14:14,499] Trial 30 finished with value: 0.5706858364900487 and parameters: {'max_depth': 8, 'learning_rate': 0.051044650086373655, 'n_estimators': 527, 'subsample': 0.8247646231609217, 'colsample_bytree': 0.7649924882867586, 'min_child_weight': 2, 'gamma': 0.08843135321489694, 'reg_alpha': 0.3793183284905538, 'reg_lambda': 1.0258914894626094, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 23 with value: 0.6284977463885927.
# [I 2026-02-07 21:14:15,318] Trial 31 finished with value: 0.6279745693735637 and parameters: {'max_depth': 3, 'learning_rate': 0.02136450574712222, 'n_estimators': 498, 'subsample': 0.709949128424093, 'colsample_bytree': 0.92556397629895, 'min_child_weight': 3, 'gamma': 0.46018219823808265, 'reg_alpha': 0.11929837931887066, 'reg_lambda': 1.3602930650080263, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 23 with value: 0.6284977463885927.
# [I 2026-02-07 21:14:16,342] Trial 32 finished with value: 0.6265132657290825 and parameters: {'max_depth': 3, 'learning_rate': 0.01345301107028254, 'n_estimators': 613, 'subsample': 0.7719522294610672, 'colsample_bytree': 0.816796115991544, 'min_child_weight': 4, 'gamma': 0.4999442179860091, 'reg_alpha': 0.09472873091376084, 'reg_lambda': 1.364280644889778, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 23 with value: 0.6284977463885927.
# [I 2026-02-07 21:14:17,305] Trial 33 finished with value: 0.6235649942760375 and parameters: {'max_depth': 3, 'learning_rate': 0.02096386754833421, 'n_estimators': 606, 'subsample': 0.6931803137801218, 'colsample_bytree': 0.8084762641095057, 'min_child_weight': 2, 'gamma': 0.46828784187785655, 'reg_alpha': 0.11330947850324767, 'reg_lambda': 1.2618334445632997, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 23 with value: 0.6284977463885927.
# [I 2026-02-07 21:14:18,481] Trial 34 finished with value: 0.5793599987924025 and parameters: {'max_depth': 3, 'learning_rate': 0.01365270115546825, 'n_estimators': 736, 'subsample': 0.7218652448984003, 'colsample_bytree': 0.8758394119923606, 'min_child_weight': 3, 'gamma': 0.49252072153031806, 'reg_alpha': 0.24627325453555904, 'reg_lambda': 1.4668322522403945, 'scale_pos_weight': 1}. Best is trial 23 with value: 0.6284977463885927.
# [I 2026-02-07 21:14:19,746] Trial 35 finished with value: 0.5709630030952458 and parameters: {'max_depth': 3, 'learning_rate': 0.02838494492634932, 'n_estimators': 860, 'subsample': 0.7916484946104034, 'colsample_bytree': 0.8187237750496894, 'min_child_weight': 5, 'gamma': 0.4732536664335797, 'reg_alpha': 0.06308651639694479, 'reg_lambda': 1.1466794216746976, 'scale_pos_weight': 1}. Best is trial 23 with value: 0.6284977463885927.
# [I 2026-02-07 21:14:20,835] Trial 36 finished with value: 0.6133658117296599 and parameters: {'max_depth': 3, 'learning_rate': 0.03951780389918702, 'n_estimators': 693, 'subsample': 0.6499271498876711, 'colsample_bytree': 0.9290593273725692, 'min_child_weight': 4, 'gamma': 0.4275399909775426, 'reg_alpha': 0.11423794306765965, 'reg_lambda': 1.3089662112728029, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 23 with value: 0.6284977463885927.
# [I 2026-02-07 21:14:21,571] Trial 37 finished with value: 0.5728225022866799 and parameters: {'max_depth': 5, 'learning_rate': 0.02101038911244074, 'n_estimators': 322, 'subsample': 0.7004241538879802, 'colsample_bytree': 0.8657193688026901, 'min_child_weight': 3, 'gamma': 0.4215190129400944, 'reg_alpha': 0.23159082898462735, 'reg_lambda': 1.7014389977679198, 'scale_pos_weight': 1}. Best is trial 23 with value: 0.6284977463885927.
# [I 2026-02-07 21:14:22,832] Trial 38 finished with value: 0.5812923161374701 and parameters: {'max_depth': 10, 'learning_rate': 0.07929058420465242, 'n_estimators': 422, 'subsample': 0.7681497781413414, 'colsample_bytree': 0.9348863304278658, 'min_child_weight': 10, 'gamma': 0.44299765265171065, 'reg_alpha': 0.04604978526780659, 'reg_lambda': 0.33312378249945485, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 23 with value: 0.6284977463885927.
# [I 2026-02-07 21:14:23,982] Trial 39 finished with value: 0.6243495773141852 and parameters: {'max_depth': 4, 'learning_rate': 0.013597587828661502, 'n_estimators': 599, 'subsample': 0.7270148289606477, 'colsample_bytree': 0.6401876930477213, 'min_child_weight': 6, 'gamma': 0.3373619033613002, 'reg_alpha': 0.13618045508689652, 'reg_lambda': 0.7283288068453193, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 23 with value: 0.6284977463885927.
# [I 2026-02-07 21:14:25,255] Trial 40 finished with value: 0.571438938913415 and parameters: {'max_depth': 3, 'learning_rate': 0.02666238375732128, 'n_estimators': 830, 'subsample': 0.6643812446892089, 'colsample_bytree': 0.9574350955651759, 'min_child_weight': 5, 'gamma': 0.49369860707726365, 'reg_alpha': 0.20155411050955596, 'reg_lambda': 1.489595326404095, 'scale_pos_weight': 1}. Best is trial 23 with value: 0.6284977463885927.
# [I 2026-02-07 21:14:26,286] Trial 41 finished with value: 0.623357928398852 and parameters: {'max_depth': 4, 'learning_rate': 0.019779795827970813, 'n_estimators': 517, 'subsample': 0.764658252082157, 'colsample_bytree': 0.6912371626758929, 'min_child_weight': 4, 'gamma': 0.38955145226957694, 'reg_alpha': 0.28991994984003183, 'reg_lambda': 1.3473316657461392, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial
 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 52 with value: 0.6299262455072098.
# [I 2026-02-07 21:14:43,326] Trial 65 finished with value: 0.6240949389420353 and parameters: {'max_depth': 4, 'learning_rate': 0.019059512709422355, 'n_estimators': 455, 'subsample': 0.627440415306247, 'colsample_bytree': 0.9269698116977584, 'min_child_weight': 9, 'gamma': 0.002446252447490931, 'reg_alpha': 0.55218091186594, 'reg_lambda': 1.845256462222944, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 52 with value: 0.6299262455072098.
# [I 2026-02-07 21:14:43,915] Trial 66 finished with value: 0.6256767440311124 and parameters: {'max_depth': 3, 'learning_rate': 0.017029578634220978, 'n_estimators': 310, 'subsample': 0.7894051806576919, 'colsample_bytree': 0.909226878759781, 'min_child_weight': 8, 'gamma': 0.13523687506621138, 'reg_alpha': 0.48185189620121227, 'reg_lambda': 1.9723587853352345, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 52 with value: 0.6299262455072098.
# [I 2026-02-07 21:14:44,845] Trial 67 finished with value: 0.617233300738199 and parameters: {'max_depth': 4, 'learning_rate': 0.02888134341937471, 'n_estimators': 500, 'subsample': 0.7548428303146635, 'colsample_bytree': 0.9975393873021728, 'min_child_weight': 9, 'gamma': 0.05129135615093315, 'reg_alpha': 0.5332383280980313, 'reg_lambda': 1.7209164243994604, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 52 with value: 0.6299262455072098.
# [I 2026-02-07 21:14:45,774] Trial 68 finished with value: 0.5747274206250156 and parameters: {'max_depth': 3, 'learning_rate': 0.022535761258159214, 'n_estimators': 572, 'subsample': 0.8092710904857003, 'colsample_bytree': 0.890781345306914, 'min_child_weight': 10, 'gamma': 0.17663466830075175, 'reg_alpha': 0.5900337866290226, 'reg_lambda': 1.872712502041965, 'scale_pos_weight': 1}. Best is trial 52 with value: 0.6299262455072098.
# [I 2026-02-07 21:14:46,554] Trial 69 finished with value: 0.6255593065837697 and parameters: {'max_depth': 3, 'learning_rate': 0.0257600111935887, 'n_estimators': 446, 'subsample': 0.6889455330830466, 'colsample_bytree': 0.9515582683208583, 'min_child_weight': 9, 'gamma': 0.0014383256384349387, 'reg_alpha': 0.7317658702687219, 'reg_lambda': 1.205672594031096, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 52 with value: 0.6299262455072098.
# [I 2026-02-07 21:14:47,464] Trial 70 finished with value: 0.6047926501171142 and parameters: {'max_depth': 5, 'learning_rate': 0.05901037592915806, 'n_estimators': 391, 'subsample': 0.8388075783881895, 'colsample_bytree': 0.9035410721783383, 'min_child_weight': 10, 'gamma': 0.08518204114244479, 'reg_alpha': 0.6354264192957311, 'reg_lambda': 1.5114792060529199, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 52 with value: 0.6299262455072098.
# [I 2026-02-07 21:14:48,561] Trial 71 finished with value: 0.62487200224354 and parameters: {'max_depth': 3, 'learning_rate': 0.010009497036781601, 'n_estimators': 530, 'subsample': 0.8952081497934088, 'colsample_bytree': 0.8614914275345009, 'min_child_weight': 7, 'gamma': 0.021282877611621037, 'reg_alpha': 0.062397292568025384, 'reg_lambda': 1.6102302547538108, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 52 with value: 0.6299262455072098.
# [I 2026-02-07 21:14:49,245] Trial 72 finished with value: 0.6305019369172468 and parameters: {'max_depth': 3, 'learning_rate': 0.014878616418793669, 'n_estimators': 352, 'subsample': 0.667275736143591, 'colsample_bytree': 0.9227396394027141, 'min_child_weight': 3, 'gamma': 0.041952592371565435, 'reg_alpha': 0.19438883640380047, 'reg_lambda': 1.427998949321776, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 72 with value: 0.6305019369172468.
# [I 2026-02-07 21:14:49,945] Trial 73 finished with value: 0.6283554453068423 and parameters: {'max_depth': 3, 'learning_rate': 0.016144968724453975, 'n_estimators': 352, 'subsample': 0.6705094985687112, 'colsample_bytree': 0.923831875747676, 'min_child_weight': 3, 'gamma': 0.1051349625626957, 'reg_alpha': 0.20487887113774333, 'reg_lambda': 1.411058299389793, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 72 with value: 0.6305019369172468.
# [I 2026-02-07 21:14:50,778] Trial 74 finished with value: 0.62346749495869 and parameters: {'max_depth': 3, 'learning_rate': 0.01155628259198365, 'n_estimators': 349, 'subsample': 0.6744803315832175, 'colsample_bytree': 0.9665331374340487, 'min_child_weight': 2, 'gamma': 0.09839635804235128, 'reg_alpha': 0.2640522368375017, 'reg_lambda': 1.3960594745658357, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 72 with value: 0.6305019369172468.
# [I 2026-02-07 21:14:51,682] Trial 75 finished with value: 0.6245255073208539 and parameters: {'max_depth': 4, 'learning_rate': 0.01681016797207702, 'n_estimators': 293, 'subsample': 0.6612811396322851, 'colsample_bytree': 0.901905709265856, 'min_child_weight': 3, 'gamma': 0.06729073631618214, 'reg_alpha': 0.19899039181251751, 'reg_lambda': 1.4328710196732586, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 72 with value: 0.6305019369172468.
# [I 2026-02-07 21:14:52,535] Trial 76 finished with value: 0.6272130702439813 and parameters: {'max_depth': 3, 'learning_rate': 0.01515390400395168, 'n_estimators': 386, 'subsample': 0.6838611429757938, 'colsample_bytree': 0.9442564592318383, 'min_child_weight': 7, 'gamma': 0.11246918167647744, 'reg_alpha': 0.3054235407075794, 'reg_lambda': 1.3213367940799299, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 72 with value: 0.6305019369172468.
# [I 2026-02-07 21:14:53,496] Trial 77 finished with value: 0.6269114279912053 and parameters: {'max_depth': 3, 'learning_rate': 0.012827471280556241, 'n_estimators': 442, 'subsample': 0.6285357299005817, 'colsample_bytree': 0.6598603268989145, 'min_child_weight': 3, 'gamma': 0.146741509339188, 'reg_alpha': 0.15757480522556258, 'reg_lambda': 1.528843029823745, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 72 with value: 0.6305019369172468.
# [I 2026-02-07 21:14:54,031] Trial 78 finished with value: 0.6255351322771517 and parameters: {'max_depth': 3, 'learning_rate': 0.04343347760992591, 'n_estimators': 243, 'subsample': 0.6557132668074048, 'colsample_bytree': 0.7674004757120514, 'min_child_weight': 2, 'gamma': 0.01767715535989419, 'reg_alpha': 0.44278795979865243, 'reg_lambda': 1.807922887499418, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 72 with value: 0.6305019369172468.
# [I 2026-02-07 21:14:54,896] Trial 79 finished with value: 0.5724569060762582 and parameters: {'max_depth': 4, 'learning_rate': 0.020373526426786283, 'n_estimators': 365, 'subsample': 0.6006370136790571, 'colsample_bytree': 0.8719904985181435, 'min_child_weight': 8, 'gamma': 0.046595439113070264, 'reg_alpha': 0.23016883468832677, 'reg_lambda': 0.4970429631022424, 'scale_pos_weight': 1}. Best is trial 72 with value: 0.6305019369172468.
# [I 2026-02-07 21:14:55,662] Trial 80 finished with value: 0.6276750603583586 and parameters: {'max_depth': 3, 'learning_rate': 0.017394814409706274, 'n_estimators': 343, 'subsample': 0.6431260759153188, 'colsample_bytree': 0.8875699047752944, 'min_child_weight': 1, 'gamma': 0.05908696573329462, 'reg_alpha': 0.35252971906155256, 'reg_lambda': 1.9078206251348584, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 72 with value: 0.6305019369172468.
# [I 2026-02-07 21:14:56,416] Trial 81 finished with value: 0.6256239773110153 and parameters: {'max_depth': 3, 'learning_rate': 0.023402827686816334, 'n_estimators': 400, 'subsample': 0.7322763602949395, 'colsample_bytree': 0.9256699932423486, 'min_child_weight': 3, 'gamma': 0.07892015128214436, 'reg_alpha': 0.13738569262430278, 'reg_lambda': 1.3608096769544276, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 72 with value: 0.6305019369172468.
# [I 2026-02-07 21:14:57,302] Trial 82 finished with value: 0.6278979846125485 and parameters: {'max_depth': 3, 'learning_rate': 0.014079735602981574, 'n_estimators': 468, 'subsample': 0.7080119424864028, 'colsample_bytree': 0.9191896531605425, 'min_child_weight': 3, 'gamma': 0.36564077453302446, 'reg_alpha': 0.09312819531885981, 'reg_lambda': 0.9765014605312217, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 72 with value: 0.6305019369172468.
# [I 2026-02-07 21:14:58,347] Trial 83 finished with value: 0.6256913360367851 and parameters: {'max_depth': 4, 'learning_rate': 0.015616690305850759, 'n_estimators': 502, 'subsample': 0.715880060500961, 'colsample_bytree': 0.9377805559476298, 'min_child_weight': 4, 'gamma': 0.10446343366692225, 'reg_alpha': 0.2007301882232871, 'reg_lambda': 1.2717119608590624, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 72 with value: 0.6305019369172468.
# [I 2026-02-07 21:14:59,309] Trial 84 finished with value: 0.6256341574242843 and parameters: {'max_depth': 3, 'learning_rate': 0.020247416747538893, 'n_estimators': 434, 'subsample': 0.697567807697499, 'colsample_bytree': 0.9589196272053822, 'min_child_weight': 3, 'gamma': 0.026634538937557833, 'reg_alpha': 0.05715494799489109, 'reg_lambda': 1.5105396767827357, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 72 with value: 0.6305019369172468.
# [I 2026-02-07 21:15:00,987] Trial 85 finished with value: 0.6158697289742994 and parameters: {'max_depth': 8, 'learning_rate': 0.011096878162813099, 'n_estimators': 273, 'subsample': 0.6737300821957709, 'colsample_bytree': 0.9079061364276633, 'min_child_weight': 2, 'gamma': 0.3093696840696709, 'reg_alpha': 0.1783901851811476, 'reg_lambda': 1.6807527543258138, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 72 with value: 0.6305019369172468.
# [I 2026-02-07 21:15:01,650] Trial 86 finished with value: 0.6262378152024696 and parameters: {'max_depth': 3, 'learning_rate': 0.031262235458491425, 'n_estimators': 314, 'subsample': 0.7532805485900299, 'colsample_bytree': 0.8206835190861131, 'min_child_weight': 5, 'gamma': 0.12443930106709697, 'reg_alpha': 0.13865418894527617, 'reg_lambda': 1.2223540292949162, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 72 with value: 0.6305019369172468.
# [I 2026-02-07 21:15:03,137] Trial 87 finished with value: 0.626069423378485 and parameters: {'max_depth': 4, 'learning_rate': 0.012752126030477423, 'n_estimators': 542, 'subsample': 0.6189106502358573, 'colsample_bytree': 0.9241822272855462, 'min_child_weight': 3, 'gamma': 0.1409360179875704, 'reg_alpha': 0.2583972373370135, 'reg_lambda': 1.4266137374747094, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 72 with value: 0.6305019369172468.
# [I 2026-02-07 21:15:04,069] Trial 88 finished with value: 0.6270451294307245 and parameters: {'max_depth': 3, 'learning_rate': 0.017696448820140872, 'n_estimators': 473, 'subsample': 0.6395461014736984, 'colsample_bytree': 0.8982359851252382, 'min_child_weight': 4, 'gamma': 0.22093014593322235, 'reg_alpha': 0.09493305281952077, 'reg_lambda': 1.3231568308136983, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 72 with value: 0.6305019369172468.
# [I 2026-02-07 21:15:05,082] Trial 89 finished with value: 0.6253910083454708 and parameters: {'max_depth': 3, 'learning_rate': 0.02733546929323518, 'n_estimators': 502, 'subsample': 0.7334345592592307, 'colsample_bytree': 0.6372190604258994, 'min_child_weight': 2, 'gamma': 0.043989508181986714, 'reg_alpha': 0.5199243227654449, 'reg_lambda': 1.380803990711439, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 72 with value: 0.6305019369172468.
# [I 2026-02-07 21:15:05,866] Trial 90 finished with value: 0.5778821652367292 and parameters: {'max_depth': 3, 'learning_rate': 0.02185632656105825, 'n_estimators': 371, 'subsample': 0.7049411805815837, 'colsample_bytree': 0.8074362982760837, 'min_child_weight': 3, 'gamma': 0.012768096354669306, 'reg_alpha': 0.6051166992047572, 'reg_lambda': 0.24808174548559248, 'scale_pos_weight': 1}. Best is trial 72 with value: 0.6305019369172468.
# [I 2026-02-07 21:15:06,743] Trial 91 finished with value: 0.6291457286670697 and parameters: {'max_depth': 3, 'learning_rate': 0.014282246816650936, 'n_estimators': 467, 'subsample': 0.7230215892170362, 'colsample_bytree': 0.9197134694953369, 'min_child_weight': 3, 'gamma': 0.3303521657879904, 'reg_alpha': 0.0956836312217137, 'reg_lambda': 0.9508875117230717, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 72 with value: 0.6305019369172468.
# [I 2026-02-07 21:15:07,754] Trial 92 finished with value: 0.6257405291054187 and parameters: {'max_depth': 3, 'learning_rate': 0.01436925957457432, 'n_estimators': 581, 'subsample': 0.7813660397480129, 'colsample_bytree': 0.9464595915220626, 'min_child_weight': 3, 'gamma': 0.45070053741022814, 'reg_alpha': 0.12574052816601305, 'reg_lambda': 0.8243660134383861, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 72 with value: 0.6305019369172468.
# [I 2026-02-07 21:15:08,518] Trial 93 finished with value: 0.6259758873856157 and parameters: {'max_depth': 3, 'learning_rate': 0.03615355575077448, 'n_estimators': 398, 'subsample': 0.7131188362539934, 'colsample_bytree': 0.9106810021786773, 'min_child_weight': 4, 'gamma': 0.27368018839282454, 'reg_alpha': 0.02813583160931768, 'reg_lambda': 1.0717369343641738, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 72 with value: 0.6305019369172468.
# [I 2026-02-07 21:15:09,321] Trial 94 finished with value: 0.6289687645787644 and parameters: {'max_depth': 3, 'learning_rate': 0.016141972394580605, 'n_estimators': 427, 'subsample': 0.7226188207117367, 'colsample_bytree': 0.8699040130163588, 'min_child_weight': 2, 'gamma': 0.3829427009951842, 'reg_alpha': 0.07828142986581457, 'reg_lambda': 0.8824420974469528, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 72 with value: 0.6305019369172468.
# [I 2026-02-07 21:15:10,128] Trial 95 finished with value: 0.628777019864091 and parameters: {'max_depth': 3, 'learning_rate': 0.01592742927992727, 'n_estimators': 430, 'subsample': 0.7244463531504814, 'colsample_bytree': 0.8727758089909848, 'min_child_weight': 1, 'gamma': 0.3855468000557533, 'reg_alpha': 0.07568338975852179, 'reg_lambda': 0.9026141990221328, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 72 with value: 0.6305019369172468.
# [I 2026-02-07 21:15:11,253] Trial 96 finished with value: 0.6273353505534613 and parameters: {'max_depth': 4, 'learning_rate': 0.01622879994499837, 'n_estimators': 438, 'subsample': 0.7432435961484497, 'colsample_bytree': 0.873504424351302, 'min_child_weight': 1, 'gamma': 0.36238760884080146, 'reg_alpha': 0.07204829565725651, 'reg_lambda': 0.948025933636661, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 72 with value: 0.6305019369172468.
# [I 2026-02-07 21:15:12,106] Trial 97 finished with value: 0.628599396913309 and parameters: {'max_depth': 3, 'learning_rate': 0.01226269841438163, 'n_estimators': 432, 'subsample': 0.7222036921521027, 'colsample_bytree': 0.8454793681647492, 'min_child_weight': 1, 'gamma': 0.38510723697587174, 'reg_alpha': 0.16077014537391074, 'reg_lambda': 0.863158609226217, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 72 with value: 0.6305019369172468.
# [I 2026-02-07 21:15:13,149] Trial 98 finished with value: 0.6263319879209281 and parameters: {'max_depth': 4, 'learning_rate': 0.012016445886377935, 'n_estimators': 423, 'subsample': 0.7245039352780114, 'colsample_bytree': 0.8403335836457205, 'min_child_weight': 1, 'gamma': 0.3853209717561906, 'reg_alpha': 0.15854297565265923, 'reg_lambda': 0.8764815778926669, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 72 with value: 0.6305019369172468.
# [I 2026-02-07 21:15:13,516] Trial 99 finished with value: 0.6124272282892724 and parameters: {'max_depth': 3, 'learning_rate': 0.010895762161073443, 'n_estimators': 136, 'subsample': 0.7329238184007048, 'colsample_bytree': 0.8569508909961495, 'min_child_weight': 1, 'gamma': 0.40459089309314883, 'reg_alpha': 0.1873665589399936, 'reg_lambda': 0.7060822527672161, 'scale_pos_weight': np.float64(2.800675675675676)}. Best is trial 72 with value: 0.6305019369172468.
# Best parameters: {'max_depth': 3, 'learning_rate': 0.014878616418793669, 'n_estimators': 352, 'subsample': 0.667275736143591, 'colsample_bytree': 0.9227396394027141, 'min_child_weight': 3, 'gamma': 0.041952592371565435, 'reg_alpha': 0.19438883640380047, 'reg_lambda': 1.427998949321776, 'scale_pos_weight': np.float64(2.800675675675676)}
# Best CV F1 score: 0.6305019369172468
#               precision    recall  f1-score   support
#
#            0       0.92      0.74      0.82      1018
#            1       0.55      0.82      0.66       389
#
#     accuracy                           0.76      1407
#    macro avg       0.73      0.78      0.74      1407
# weighted avg       0.81      0.76      0.77      1407

# %%
# Save this model

import joblib

# Save the best model to a .pkl file
joblib.dump(best_model_optuna, 'best_optuna_churn_model.pkl')

print("Best model successfully saved as 'best_optuna_churn_model.pkl'")
# Out:
# Best model successfully saved as 'best_optuna_churn_model.pkl'

# %%
# Save this model

import joblib

# Save the best model to a .pkl file
joblib.dump(model_ada_weighted, 'ada_boost_churn_model.pkl')

print("Best model successfully saved as 'ada_boost_churn_model.pkl'")
# Out:
# Best model successfully saved as 'ada_boost_churn_model.pkl'
